# %%
import scipy.misc as misc
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
pwd
# Out:
# '/Users/mac/Documents/ESRGAN'

# %%
ls
# Out:
# LICENSE          README.md        block.py         net_interp.py
# LR/              Untitled.ipynb   figures/         results/
# QA.md            architecture.py  models/          test.py

# %%
img = plt.imread('LR/lr1.png')
img_sm = misc.imresize(img, 2.0, interp='bilinear')
# Out:
# /Users/mac/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
plt.imshow(img)

# %%
plt.imshow(img_sm)

# %%
plt.imshow(img, interpolation='bicubic')

# %%
plt.imsave('testsave.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-3c94c904928a> in <module>
# ----> 1 plt.imsave('testsave.png')
#
# TypeError: imsave() missing 1 required positional argument: 'arr'

# %%
misc.imsave("lr1_bicubic.png", img_sm, interpolation='bicubic')
# Out:
# /Users/mac/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-333ad6e19182> in <module>
# ----> 1 misc.imsave("lr1_bicubic.png", img_sm, interpolation='bicubic')
#
# /usr/local/lib/python3.7/site-packages/numpy/lib/utils.py in newfunc(*args, **kwds)
#      99             """`arrayrange` is deprecated, use `arange` instead!"""
#     100             warnings.warn(depdoc, DeprecationWarning, stacklevel=2)
# --> 101             return func(*args, **kwds)
#     102
#     103         newfunc = _set_function_name(newfunc, old_name)
#
# TypeError: imsave() got an unexpected keyword argument 'interpolation'
